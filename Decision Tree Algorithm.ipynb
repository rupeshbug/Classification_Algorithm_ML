# %% [markdown]
# ### Import relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, accuracy_score

# %%
data = load_iris()

# %% [markdown]
# ### Store the inputs in varible X and target in y

# %%
X, y = data.data, data.target

# %% [markdown]
# ### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %% [markdown]
# ### Creating the decision tree

# %%
#storing the instance in the variable named clf
clf = DecisionTreeClassifier()

# training the model
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Testing the model

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([2, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 2, 0, 0, 2, 1, 1, 2, 2, 2, 2, 0,
#        2, 0, 1, 2, 1, 0, 1, 2])

# %% [markdown]
# ### Evaluating the model

# %%
accuracy = accuracy_score(y_test, y_pred)*100
print(f"The accuracy of the model is {accuracy.round(2)}%")
# Out:
# The accuracy of the model is 96.67%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.83      0.91         6
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ### Visualizing the decision tree

# %%
plot_tree(clf)
# Out:
# [Text(0.4, 0.9, 'X[2] <= 2.45\ngini = 0.665\nsamples = 120\nvalue = [39, 44, 37]'),
#  Text(0.2, 0.7, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.6, 0.7, 'X[3] <= 1.65\ngini = 0.496\nsamples = 81\nvalue = [0, 44, 37]'),
#  Text(0.4, 0.5, 'X[2] <= 4.95\ngini = 0.156\nsamples = 47\nvalue = [0, 43, 4]'),
#  Text(0.2, 0.3, 'gini = 0.0\nsamples = 42\nvalue = [0, 42, 0]'),
#  Text(0.6, 0.3, 'X[0] <= 6.05\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.4, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.5, 'gini = 0.057\nsamples = 34\nvalue = [0, 1, 33]')]

# %%
plt.figure(figsize=(15,12))
plot_tree(clf, filled = True,
             feature_names = ["Sepal Length", "Sepal Width", "Petal Length", "Petal Width"],
             class_names = ["Setosa", "Versicolour", "Virginica"]
         )
plt.show()
